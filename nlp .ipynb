# %% [markdown]
# # Read CSV in pandas

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
qs_df = pd.read_csv('/kaggle/input/exp-dataset/questions_surevey_en.csv')

# %%
qs_df
# Out:
#                                               Common Symptoms  \
# 0                4. What are the common symptoms of COVID-19?
# 1          19. Have you had any discomfort after vaccination?
# 2        1. How is COVID 19 passed or transmitted to people?
# 3  10. How do masks help to avoid getting sick with COVID 19?
#
#   Discomfort while vaccinate  How is COVID 19 transmitted to people?  \
# 0                                                                NaN
# 1                                                                NaN
# 2                        NaN                                     NaN
# 3                        NaN                                     NaN
#
#    How mask help  Reuse mask  Time get infected  What is vaccination  \
# 0            NaN         NaN                NaN                  NaN
# 1            NaN         NaN                NaN                  NaN
# 2            NaN         NaN                NaN                  NaN
# 3            NaN         NaN                NaN                  NaN
#
#    when mask  when medical attention  why not vaccinate  why recommend vaccine
# 0        NaN                     NaN                NaN                    NaN
# 1        NaN                     NaN                NaN                    NaN
# 2        NaN                     NaN                NaN                    NaN
# 3        NaN                     NaN                NaN                    NaN

# %%
np_qs_df  = qs_df.values
np_qs_df = np_qs_df[0]

# %%
np_qs_df
# Out:
# array(['4. What are the common symptoms of COVID-19?', ' ', nan, nan, nan,
#        nan, nan, nan, nan, nan, nan], dtype=object)

# %% [markdown]
# # Reading the reference text

# %%
# Reference corpus
ref_df = pd.read_csv('/kaggle/input/exp-dataset/ref.csv')

# %%
ref_df
# Out:
#                                                                          Common Symptoms  \
# 0  Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing
#
#   Discomfort while vaccinate  \
# 0      fever and muscle pain
#
#                                How is COVID 19 transmitted to people?  \
# 0  It is transmitted by respiratory droplets that contain the virus.
#
#                                                                                                                                                                                                                                                   How mask help  \
# 0  They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus. If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.
#
#                                                                                                                    Reuse mask  \
# 0  Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.
#
#                                                                                                                                                      Time get infected  \
# 0  The incubation period ranges from 1 to 14 days. The most common is that it is 5-6 days, and in some rare cases it has been reported that it is longer than 14 days.
#
#                                                                  What is vaccination  \
# 0  It is the process of acquired immunization, defense antibodies against the virus.
#
#                                                                              when mask  \
# 0  Especially in closed public places, but it is also useful in outdoor public places.
#
#                                                  when medical attention  \
# 0  If symptoms such as shortness of breath or lack of oxygenation occur
#
#                                                                                                                                                                                                                                                                                                                         why not vaccinate  \
# 0  The two main reasons to get vaccinated are to protect ourselves and to protect those around us. Because not everyone can get vaccinated, including very young babies, those who are seriously ill, or have certain allergies. They depend on others being vaccinated to make sure they too are safe from vaccine-preventable diseases.
#
#                              why recommend vaccine
# 0  It is the only effective way to stop pandemics.

# %%
np_ref_df  = ref_df.values
np_ref_df = np_ref_df[0]

# %%
len(np_ref_df)
# Out:
# 11

# %%
np_ref_df
# Out:
# array(['Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing',
#        'fever and muscle pain',
#        'It is transmitted by respiratory droplets that contain the virus. ',
#        'They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus. If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose. ',
#        'Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.',
#        'The incubation period ranges from 1 to 14 days. The most common is that it is 5-6 days, and in some rare cases it has been reported that it is longer than 14 days.',
#        'It is the process of acquired immunization, defense antibodies against the virus.',
#        'Especially in closed public places, but it is also useful in outdoor public places.',
#        'If symptoms such as shortness of breath or lack of oxygenation occur',
#        'The two main reasons to get vaccinated are to protect ourselves and to protect those around us. Because not everyone can get vaccinated, including very young babies, those who are seriously ill, or have certain allergies. They depend on others being vaccinated to make sure they too are safe from vaccine-preventable diseases.',
#        'It is the only effective way to stop pandemics.'], dtype=object)

# %%
import nltk
nltk.download('punkt')
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [nltk_data] Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# reading the reference text 
# Tokenize into sentences
# Putting into array of arrays
from nltk.tokenize import sent_tokenize
rf_df_sentences=[]

for col in ref_df.columns:
    
    sent = ref_df[col][0]
    sentences = sent_tokenize(sent)
    rf_df_sentences.append(sentences)
    

rf_df_sentences
# Out:
# [['Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing'],
#  ['fever and muscle pain'],
#  ['It is transmitted by respiratory droplets that contain the virus.'],
#  ['They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus.',
#   'If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.'],
#  ['Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.'],
#  ['The incubation period ranges from 1 to 14 days.',
#   'The most common is that it is 5-6 days, and in some rare cases it has been reported that it is longer than 14 days.'],
#  ['It is the process of acquired immunization, defense antibodies against the virus.'],
#  ['Especially in closed public places, but it is also useful in outdoor public places.'],
#  ['If symptoms such as shortness of breath or lack of oxygenation occur'],
#  ['The two main reasons to get vaccinated are to protect ourselves and to protect those around us.',
#   'Because not everyone can get vaccinated, including very young babies, those who are seriously ill, or have certain allergies.',
#   'They depend on others being vaccinated to make sure they too are safe from vaccine-preventable diseases.'],
#  ['It is the only effective way to stop pandemics.']]

# %% [markdown]
# # Reading the Surveys

# %%
survey_df = pd.read_csv('/kaggle/input/exp-dataset/qc_output_en.csv')
survey_df[:1]
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[34], line 3
#       1 survey_df = pd.read_csv('/kaggle/input/exp-dataset/qc_output_en.csv')
#       2 survey_df[:1]
# ----> 3 es_surevey_df = pd.read_csv('/kaggle/input/translated-output/qc_output_sp.csv')
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File /opt/conda/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:93, in CParserWrapper.__init__(self, src, **kwds)
#      90 if kwds["dtype_backend"] == "pyarrow":
#      91     # Fail here loudly instead of in cython after reading
#      92     import_optional_dependency("pyarrow")
# ---> 93 self._reader = parsers.TextReader(src, **kwds)
#      95 self.unnamed_cols = self._reader.unnamed_cols
#      97 # error: Cannot determine type of 'names'
#
# File parsers.pyx:579, in pandas._libs.parsers.TextReader.__cinit__()
#
# File parsers.pyx:668, in pandas._libs.parsers.TextReader._get_header()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2050, in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xed in position 1: invalid continuation byte

# %%
survey_df.shape[0]
#df.shape
# Out:
# 4

# %%
from nltk.tokenize import sent_tokenize
survey_df_sentences=[]


for row in range(survey_df.shape[0]):
    row_sentences=[]
    for col in survey_df.columns:
        sent = survey_df[col][row]
        sentences = sent_tokenize(sent)
        row_sentences.append(sentences)
    print("-----------------")
    survey_df_sentences.append(row_sentences)
    sentences = sent_tokenize(sent)
    rf_df_sentences.append(sentences)
    

rf_df_sentences
# Out:
# -----------------
# -----------------
# -----------------
# -----------------
# [['Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing'],
#  ['fever and muscle pain'],
#  ['It is transmitted by respiratory droplets that contain the virus.'],
#  ['They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus.',
#   'If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.'],
#  ['Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.'],
#  ['The incubation period ranges from 1 to 14 days.',
#   'The most common is that it is 5-6 days, and in some rare cases it has been reported that it is longer than 14 days.'],
#  ['It is the process of acquired immunization, defense antibodies against the virus.'],
#  ['Especially in closed public places, but it is also useful in outdoor public places.'],
#  ['If symptoms such as shortness of breath or lack of oxygenation occur'],
#  ['The two main reasons to get vaccinated are to protect ourselves and to protect those around us.',
#   'Because not everyone can get vaccinated, including very young babies, those who are seriously ill, or have certain allergies.',
#   'They depend on others being vaccinated to make sure they too are safe from vaccine-preventable diseases.'],
#  ['It is the only effective way to stop pandemics.'],
#  ['It is one of the most effective procedures for the prevention of infectious diseases, such as COVID-19'],
#  ['There is no risk when getting vaccinated, vaccination is the most important preventive measure both for personal care'],
#  ['To prevent them from spreading or to end the pandemic'],
#  ['It is the only effective way to stop pandemics.']]

# %%
survey_df_sentences[2]
# Out:
# [['Flu-like symptoms plus loss of taste and smell.',
#   'Also pain in the lung area and shortness of breath'],
#  ['Pain at the injection site'],
#  ['By air with virus particles present in the environment and less frequently with virus particles on surfaces'],
#  ['They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus.',
#   'If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.'],
#  ['Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.'],
#  ['About 3 to 4 days, but it can take up to 2 weeks'],
#  ['The procedure for inoculating people with viruses or variants of genetic material to achieve antibody resistance'],
#  ['Especially in closed public places, but it is also useful in outdoor public places'],
#  ['If symptoms such as shortness of breath or lack of oxygenation occur'],
#  ['You should be vaccinated to prevent the spread of a disease or lessen symptoms in the event of contracting a disease.',
#   'In addition to eventually eradicating the disease'],
#  ['To prevent them from spreading or to end the pandemic']]

# %%
len(survey_df_sentences)
# Out:
# 4

# %% [markdown]
# # Now Creating the Same report as report_output

# %%
# !pip install torch==1.2.0 torchvision==0.4.0 -f
# !pip install -U sentence-transformers
# Out:
# Usage:
#   pip install [options] <requirement specifier> [package-index-options] ...
#   pip install [options] -r <requirements file> [package-index-options] ...
#   pip install [options] [-e] <vcs project url> ...
#   pip install [options] [-e] <local project path> ...
#   pip install [options] <archive url/path> ...
#
# -f option requires 1 argument
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.35.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (2.0.0)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.15.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (1.11.3)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (3.2.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from sentence-transformers) (0.17.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.10.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence-transformers) (21.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2023.8.8)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (0.4.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->sentence-transformers) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->sentence-transformers) (10.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=a3abf72d00b45fcdded9bb31c50bf3a3efe326bc60f36102442dfe5c333819de
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.2.2

# %%
from sentence_transformers import SentenceTransformer
model_p = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# Out:
# Downloading .gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# We will create the same type of output but now instead of considering all the sentences,
# will consider sentences individually

import csv
from sentence_transformers import  util

# Creading a CSV writer 
outFile = open('report1.csv', 'w')
writer_rep = csv.writer(outFile)

# Middle portion

lst_ref = []
lst_pas = []

#for col in qs_df.columns:
for col in range(len(np_qs_df)):
    # Clear it 
    lst_ref = []
    lst_pas = []
    
    print("=====================================")
    print("Question : ", np_qs_df[col])
    writer_rep.writerow(())
    writer_rep.writerow(('Question',  
                     np_qs_df[col], 
                     '',
                     '',
                     ''))
    print("Reference text : ", np_ref_df[col])

    writer_rep.writerow(('Reference text',  
                     np_ref_df[col], 
                     '',
                     '',
                     ''))
    writer_rep.writerow(())
    
    writer_rep.writerow(('Serial', 
                     'Reference text', 
                     'User Text', 
                     'Ref Sim Score',
                     'Qs Sim Score'))
    
    for row in range(len(survey_df_sentences)):
        
        print(row, len(rf_df_sentences[col]))
        lst_pas = survey_df_sentences[row][col]
        print(survey_df_sentences[row][col], len(survey_df_sentences[row][col]))
        
        
        for ref_part in range(len(rf_df_sentences[col])):
            q_part_txt= rf_df_sentences[col][ref_part]
            
            #     # Getting the embedding
            q_emb = model_p.encode(q_part_txt)
            p_emb = model_p.encode(lst_pas)
            #     # Printing the similarity score 
            print("Similarity on bigger:", util.pytorch_cos_sim(q_emb, p_emb))
            sim_score = util.pytorch_cos_sim(q_emb, p_emb).cpu().detach().numpy()[0]
            
            #  Getting the embedding for comparing similarity with the question
            #q_emb_Q = model_p.encode(np_qs_df[col])
            #     # Printing the similarity score 
            print("Similarity on bigger:", util.pytorch_cos_sim(q_emb_Q, p_emb))
            sim_score_qs = util.pytorch_cos_sim(q_emb_Q, p_emb).cpu().detach().numpy()[0]
            
            i = 0 
            
            # Writing in the File
            for pass_text in lst_pas:
                writer_rep.writerow((row+1, 
                             q_part_txt, 
                             pass_text, 
                             sim_score[i],
                             sim_score_qs[i]))
                i = i + 1
        
# Closing the output file
outFile.close()
# Out:
# =====================================
# Question :  4. What are the common symptoms of COVID-19?
# Reference text :  Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing
# 0 1
# ['COMMON SYMPTOMS Fever Cough General malaise Loss of taste or smell UN COMMON SYMPTOMS: Sore throat Headache Diarrhea Skin rash Irritated eyes SYMPTOMS - COMPLICATIONS: Difficulty breathing or dyspnea Lethargy Chest pain'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7371]])
# Similarity on bigger: tensor([[-0.0787]])
# 1 1
# ['Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[0.0155]])
# 2 1
# ['Flu-like symptoms plus loss of taste and smell.', 'Also pain in the lung area and shortness of breath'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7349, 0.5639]])
# Similarity on bigger: tensor([[ 0.0281, -0.0991]])
# 3 1
# ['Cough, fever, myalgia, dyspnea, malaise.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6446]])
# Similarity on bigger: tensor([[-0.0364]])
# =====================================
# Question :
# Reference text :  fever and muscle pain
# 0 1
# ['Yes, general malaise for 1 night .'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.2565]])
# Similarity on bigger: tensor([[0.0503]])
# 1 1
# ['Yes, in the second vaccination I had a fever and muscle pain.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5436]])
# Similarity on bigger: tensor([[-0.0525]])
# 2 1
# ['Pain at the injection site'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3471]])
# Similarity on bigger: tensor([[0.0272]])
# 3 1
# ['Yes.', 'General malaise, fever, myalgia, headache.'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.0018, 0.5426]])
# Similarity on bigger: tensor([[ 0.2301, -0.0343]])
# =====================================
# Question :  nan
# Reference text :  It is transmitted by respiratory droplets that contain the virus.
# 0 1
# [' Direct contact, transmission by air and by droplets.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5568]])
# Similarity on bigger: tensor([[-0.0508]])
# 1 1
# [' Through indirect or direct contact with secretions infected by the virus.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7537]])
# Similarity on bigger: tensor([[-0.0415]])
# 2 1
# ['By air with virus particles present in the environment and less frequently with virus particles on surfaces'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7287]])
# Similarity on bigger: tensor([[-0.0334]])
# 3 1
# ['It is transmitted by respiratory droplets that contain the virus.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[-0.0530]])
# =====================================
# Question :  nan
# Reference text :  They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus. If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.
# 0 2
# [' Avoiding transmission by direct contact, transmission by air and by droplets'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4360]])
# Similarity on bigger: tensor([[-0.0103]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.2911]])
# Similarity on bigger: tensor([[-0.0103]])
# 1 2
# [' They prevent the transfer of contaminated secretions from one person to another.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6524]])
# Similarity on bigger: tensor([[0.0076]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6490]])
# Similarity on bigger: tensor([[0.0076]])
# 2 2
# ['They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus.', 'If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000, 0.6550]])
# Similarity on bigger: tensor([[ 0.0198, -0.0156]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6550, 1.0000]])
# Similarity on bigger: tensor([[ 0.0198, -0.0156]])
# 3 2
# ['It is a barrier method that prevents virus particles from coming into contact with the respiratory tract.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7007]])
# Similarity on bigger: tensor([[-0.0228]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7582]])
# Similarity on bigger: tensor([[-0.0228]])
# =====================================
# Question :  nan
# Reference text :  Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.
# 0 1
# [" The use of a mask depends on the individual's site of exposure, preferably they should be use surgical masks or disposable KN95."] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4907]])
# Similarity on bigger: tensor([[-0.0420]])
# 1 1
# ['No.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.1468]])
# Similarity on bigger: tensor([[0.1833]])
# 2 1
# ['Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[0.0276]])
# 3 1
# ['No, each mask has a useful life time'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6372]])
# Similarity on bigger: tensor([[0.0038]])
# =====================================
# Question :  nan
# Reference text :  The incubation period ranges from 1 to 14 days. The most common is that it is 5-6 days, and in some rare cases it has been reported that it is longer than 14 days.
# 0 2
# ['A range of 5 to 10 days with a common average of 7 days.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5676]])
# Similarity on bigger: tensor([[-0.0350]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.8621]])
# Similarity on bigger: tensor([[-0.0350]])
# 1 2
# ['Between six and fifteen days'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5600]])
# Similarity on bigger: tensor([[0.0431]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.8329]])
# Similarity on bigger: tensor([[0.0431]])
# 2 2
# ['About 3 to 4 days, but it can take up to 2 weeks'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4495]])
# Similarity on bigger: tensor([[-0.0206]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.8626]])
# Similarity on bigger: tensor([[-0.0206]])
# 3 2
# ['It can take between 2 to 14 days.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4584]])
# Similarity on bigger: tensor([[-0.0024]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.8523]])
# Similarity on bigger: tensor([[-0.0024]])
# =====================================
# Question :  nan
# Reference text :  It is the process of acquired immunization, defense antibodies against the virus.
# 0 1
# ['Immunization is the process by which a person becomes immune or resistant to an infectious disease, usually through the administration of a vaccine.', "Vaccines stimulate the body's own immune system to protect the person against infection or disease.", 'later.', 'WHO'] 4
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[ 0.7231,  0.5731, -0.0180,  0.0285]])
# Similarity on bigger: tensor([[-0.0022,  0.0010,  0.2303,  0.2490]])
# 1 1
# ['It is the process of acquired immunization, defense antibodies against the virus.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[-0.0043]])
# 2 1
# ['The procedure for inoculating people with viruses or variants of genetic material to achieve antibody resistance'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7198]])
# Similarity on bigger: tensor([[0.0727]])
# 3 1
# ['It is the process by which a vaccine is administered so that a person or animal becomes resistant or immune to a disease.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.8110]])
# Similarity on bigger: tensor([[0.0059]])
# =====================================
# Question :  nan
# Reference text :  Especially in closed public places, but it is also useful in outdoor public places.
# 0 1
# ['Whenever we are in contact with another person.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3162]])
# Similarity on bigger: tensor([[0.1064]])
# 1 1
# ['All the time when leaving home.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3316]])
# Similarity on bigger: tensor([[0.1134]])
# 2 1
# ['Especially in closed public places, but it is also useful in outdoor public places'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.9961]])
# Similarity on bigger: tensor([[0.0598]])
# 3 1
# ['When we are in public places where social distancing cannot be maintained.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4252]])
# Similarity on bigger: tensor([[0.0619]])
# =====================================
# Question :  nan
# Reference text :  If symptoms such as shortness of breath or lack of oxygenation occur
# 0 1
# ['Medical attention should be sought according to the symptoms in the different levels of health care.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4329]])
# Similarity on bigger: tensor([[0.0107]])
# 1 1
# ['When the first symptoms have appeared and you suspect that you have been in contact with a positive COVID-19 patient.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3360]])
# Similarity on bigger: tensor([[-0.0204]])
# 2 1
# ['If symptoms such as shortness of breath or lack of oxygenation occur'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[-0.0929]])
# 3 1
# ['Having a very high fever that does not settle to medication, having significant dyspnea.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6292]])
# Similarity on bigger: tensor([[-0.0695]])
# =====================================
# Question :  nan
# Reference text :  The two main reasons to get vaccinated are to protect ourselves and to protect those around us. Because not everyone can get vaccinated, including very young babies, those who are seriously ill, or have certain allergies. They depend on others being vaccinated to make sure they too are safe from vaccine-preventable diseases.
# 0 3
# ['They must be vaccinated since it is one of the most effective procedures for the prevention of infectious diseases.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7454]])
# Similarity on bigger: tensor([[0.0321]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6533]])
# Similarity on bigger: tensor([[0.0321]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7189]])
# Similarity on bigger: tensor([[0.0321]])
# 1 3
# ['Yes, they must be vaccinated, to stop the infections in the population.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6664]])
# Similarity on bigger: tensor([[0.0211]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5722]])
# Similarity on bigger: tensor([[0.0211]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6725]])
# Similarity on bigger: tensor([[0.0211]])
# 2 3
# ['You should be vaccinated to prevent the spread of a disease or lessen symptoms in the event of contracting a disease.', 'In addition to eventually eradicating the disease'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.8701, 0.3576]])
# Similarity on bigger: tensor([[0.0007, 0.0798]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6995, 0.2341]])
# Similarity on bigger: tensor([[0.0007, 0.0798]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6843, 0.3490]])
# Similarity on bigger: tensor([[0.0007, 0.0798]])
# 3 3
# ['People who have an allergy to any of the components of the vaccine or a state of immunosuppression should not be vaccinated without the permission of their treating physician.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5697]])
# Similarity on bigger: tensor([[-0.0252]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7201]])
# Similarity on bigger: tensor([[-0.0252]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6119]])
# Similarity on bigger: tensor([[-0.0252]])
# =====================================
# Question :  nan
# Reference text :  It is the only effective way to stop pandemics.
# 0 1
# ['It is one of the most effective procedures for the prevention of infectious diseases, such as COVID-19'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6267]])
# Similarity on bigger: tensor([[0.0224]])
# 1 1
# ['There is no risk when getting vaccinated, vaccination is the most important preventive measure both for personal care'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3299]])
# Similarity on bigger: tensor([[-0.0459]])
# 2 1
# ['To prevent them from spreading or to end the pandemic'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7166]])
# Similarity on bigger: tensor([[0.0758]])
# 3 1
# ['It is the only effective way to stop pandemics.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[0.1633]])

# %%
import csv
from sentence_transformers import SentenceTransformer, util

def load_model(model_name):
    return SentenceTransformer(model_name)

def calculate_similarity(model, q_text, p_texts):
    q_emb = model.encode(q_text)
    p_emb = model.encode(p_texts)
    return util.pytorch_cos_sim(q_emb, p_emb).cpu().detach().numpy()

def write_to_csv(file_path, data):
    with open(file_path, 'w', newline='') as csv_file:
        csv_writer = csv.writer(csv_file)
        csv_writer.writerows(data)

def main():
    model_name = "paraphrase-distilroberta-base-v1"  # Replace with your actual model name or path
    model = load_model(model_name)

    # Rest of your code for iterating through questions, reference texts, and user texts

    # Example data to write to CSV
    csv_data = [
        ['Serial', 'Reference text', 'User Text', 'Ref Sim Score', 'Qs Sim Score'],
        # ... add your data rows here
    ]
    # Creading a CSV writer 
    outFile = open('report1.csv', 'w')
    writer_rep = csv.writer(outFile)

    # Middle portion

    lst_ref = []
    lst_pas = []

    #for col in qs_df.columns:
    for col in range(len(np_qs_df)):
        # Clear it 
        lst_ref = []
        lst_pas = []

        print("=====================================")
        print("Question : ", np_qs_df[col])
        writer_rep.writerow(())
        writer_rep.writerow(('Question',  
                         np_qs_df[col], 
                         '',
                         '',
                         ''))
        print("Reference text : ", np_ref_df[col])

        writer_rep.writerow(('Reference text',  
                         np_ref_df[col], 
                         '',
                         '',
                         ''))
        writer_rep.writerow(())

        writer_rep.writerow(('Serial', 
                         'Reference text', 
                         'User Text', 
                         'Ref Sim Score',
                         'Qs Sim Score'))

        for row in range(len(survey_df_sentences)):

            print(row, len(rf_df_sentences[col]))
            lst_pas = survey_df_sentences[row][col]
            print(survey_df_sentences[row][col], len(survey_df_sentences[row][col]))


            for ref_part in range(len(rf_df_sentences[col])):
                q_part_txt= rf_df_sentences[col][ref_part]

                #     # Getting the embedding
                q_emb = model.encode(q_part_txt)
                p_emb = model.encode(lst_pas)
                #     # Printing the similarity score 
                print("Similarity on bigger:", util.pytorch_cos_sim(q_emb, p_emb))
                sim_score = util.pytorch_cos_sim(q_emb, p_emb).cpu().detach().numpy()[0]

                #  Getting the embedding for comparing similarity with the question
                #q_emb_Q = model.encode(np_qs_df[col])
                #     # Printing the similarity score 
                print("Similarity on bigger:", util.pytorch_cos_sim(q_emb_Q, p_emb))
                sim_score_qs = util.pytorch_cos_sim(q_emb_Q, p_emb).cpu().detach().numpy()[0]

                i = 0 

                # Writing in the File
                for pass_text in lst_pas:
                    writer_rep.writerow((row+1, 
                                 q_part_txt, 
                                 pass_text, 
                                 sim_score[i],
                                 sim_score_qs[i]))
                    i = i + 1

    # Closing the output file
    outFile.close()

    

if __name__ == "__main__":
    main()
# Out:
# =====================================
# Question :  4. What are the common symptoms of COVID-19?
# Reference text :  Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing
# 0 1
# ['COMMON SYMPTOMS Fever Cough General malaise Loss of taste or smell UN COMMON SYMPTOMS: Sore throat Headache Diarrhea Skin rash Irritated eyes SYMPTOMS - COMPLICATIONS: Difficulty breathing or dyspnea Lethargy Chest pain'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6136]])
# Similarity on bigger: tensor([[-0.0272]])
# 1 1
# ['Headache General weakness Cough Loss of smell and taste Vomiting Difficulty breathing'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[-0.0046]])
# 2 1
# ['Flu-like symptoms plus loss of taste and smell.', 'Also pain in the lung area and shortness of breath'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5405, 0.6004]])
# Similarity on bigger: tensor([[ 0.0295, -0.0549]])
# 3 1
# ['Cough, fever, myalgia, dyspnea, malaise.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3153]])
# Similarity on bigger: tensor([[-0.0499]])
# =====================================
# Question :
# Reference text :  fever and muscle pain
# 0 1
# ['Yes, general malaise for 1 night .'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[-0.0132]])
# Similarity on bigger: tensor([[-0.0056]])
# 1 1
# ['Yes, in the second vaccination I had a fever and muscle pain.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3779]])
# Similarity on bigger: tensor([[0.0269]])
# 2 1
# ['Pain at the injection site'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3132]])
# Similarity on bigger: tensor([[0.0012]])
# 3 1
# ['Yes.', 'General malaise, fever, myalgia, headache.'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.1496, 0.3920]])
# Similarity on bigger: tensor([[ 0.0460, -0.0333]])
# =====================================
# Question :  nan
# Reference text :  It is transmitted by respiratory droplets that contain the virus.
# 0 1
# [' Direct contact, transmission by air and by droplets.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5206]])
# Similarity on bigger: tensor([[0.0177]])
# 1 1
# [' Through indirect or direct contact with secretions infected by the virus.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5322]])
# Similarity on bigger: tensor([[0.0253]])
# 2 1
# ['By air with virus particles present in the environment and less frequently with virus particles on surfaces'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5475]])
# Similarity on bigger: tensor([[0.0483]])
# 3 1
# ['It is transmitted by respiratory droplets that contain the virus.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.]])
# Similarity on bigger: tensor([[0.0288]])
# =====================================
# Question :  nan
# Reference text :  They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus. If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.
# 0 2
# [' Avoiding transmission by direct contact, transmission by air and by droplets'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4197]])
# Similarity on bigger: tensor([[0.0288]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3784]])
# Similarity on bigger: tensor([[0.0288]])
# 1 2
# [' They prevent the transfer of contaminated secretions from one person to another.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4679]])
# Similarity on bigger: tensor([[0.0194]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5115]])
# Similarity on bigger: tensor([[0.0194]])
# 2 2
# ['They prevent transmission to a certain extent if we have the virus by blocking a good part of the particles that we emit that may contain the virus.', 'If one does not have the virus, it helps to avoid the entry of similar particles to the mouth or nose.'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000, 0.7257]])
# Similarity on bigger: tensor([[0.0874, 0.0504]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7257, 1.0000]])
# Similarity on bigger: tensor([[0.0874, 0.0504]])
# 3 2
# ['It is a barrier method that prevents virus particles from coming into contact with the respiratory tract.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6413]])
# Similarity on bigger: tensor([[0.0407]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6329]])
# Similarity on bigger: tensor([[0.0407]])
# =====================================
# Question :  nan
# Reference text :  Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.
# 0 1
# [" The use of a mask depends on the individual's site of exposure, preferably they should be use surgical masks or disposable KN95."] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5866]])
# Similarity on bigger: tensor([[0.0557]])
# 1 1
# ['No.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.2464]])
# Similarity on bigger: tensor([[0.0750]])
# 2 1
# ['Yes it is possible but only to a certain extent depending on the type of mask for a limited time, but it is not advisable.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[0.0666]])
# 3 1
# ['No, each mask has a useful life time'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4718]])
# Similarity on bigger: tensor([[0.0227]])
# =====================================
# Question :  nan
# Reference text :  The incubation period ranges from 1 to 14 days. The most common is that it is 5-6 days, and in some rare cases it has been reported that it is longer than 14 days.
# 0 2
# ['A range of 5 to 10 days with a common average of 7 days.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5438]])
# Similarity on bigger: tensor([[-0.0159]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6876]])
# Similarity on bigger: tensor([[-0.0159]])
# 1 2
# ['Between six and fifteen days'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4271]])
# Similarity on bigger: tensor([[-0.0285]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5444]])
# Similarity on bigger: tensor([[-0.0285]])
# 2 2
# ['About 3 to 4 days, but it can take up to 2 weeks'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5715]])
# Similarity on bigger: tensor([[-0.0387]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6376]])
# Similarity on bigger: tensor([[-0.0387]])
# 3 2
# ['It can take between 2 to 14 days.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6213]])
# Similarity on bigger: tensor([[-0.0339]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6602]])
# Similarity on bigger: tensor([[-0.0339]])
# =====================================
# Question :  nan
# Reference text :  It is the process of acquired immunization, defense antibodies against the virus.
# 0 1
# ['Immunization is the process by which a person becomes immune or resistant to an infectious disease, usually through the administration of a vaccine.', "Vaccines stimulate the body's own immune system to protect the person against infection or disease.", 'later.', 'WHO'] 4
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6431, 0.5361, 0.1165, 0.1324]])
# Similarity on bigger: tensor([[ 0.0881,  0.0499,  0.0369, -0.0033]])
# 1 1
# ['It is the process of acquired immunization, defense antibodies against the virus.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[0.0542]])
# 2 1
# ['The procedure for inoculating people with viruses or variants of genetic material to achieve antibody resistance'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6619]])
# Similarity on bigger: tensor([[0.0188]])
# 3 1
# ['It is the process by which a vaccine is administered so that a person or animal becomes resistant or immune to a disease.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6267]])
# Similarity on bigger: tensor([[0.0876]])
# =====================================
# Question :  nan
# Reference text :  Especially in closed public places, but it is also useful in outdoor public places.
# 0 1
# ['Whenever we are in contact with another person.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.1266]])
# Similarity on bigger: tensor([[-0.0147]])
# 1 1
# ['All the time when leaving home.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.1934]])
# Similarity on bigger: tensor([[0.0381]])
# 2 1
# ['Especially in closed public places, but it is also useful in outdoor public places'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.9868]])
# Similarity on bigger: tensor([[-0.0203]])
# 3 1
# ['When we are in public places where social distancing cannot be maintained.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4302]])
# Similarity on bigger: tensor([[-0.0005]])
# =====================================
# Question :  nan
# Reference text :  If symptoms such as shortness of breath or lack of oxygenation occur
# 0 1
# ['Medical attention should be sought according to the symptoms in the different levels of health care.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4048]])
# Similarity on bigger: tensor([[0.0279]])
# 1 1
# ['When the first symptoms have appeared and you suspect that you have been in contact with a positive COVID-19 patient.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.2749]])
# Similarity on bigger: tensor([[0.0202]])
# 2 1
# ['If symptoms such as shortness of breath or lack of oxygenation occur'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.0000]])
# Similarity on bigger: tensor([[0.0355]])
# 3 1
# ['Having a very high fever that does not settle to medication, having significant dyspnea.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.3708]])
# Similarity on bigger: tensor([[0.0232]])
# =====================================
# Question :  nan
# Reference text :  The two main reasons to get vaccinated are to protect ourselves and to protect those around us. Because not everyone can get vaccinated, including very young babies, those who are seriously ill, or have certain allergies. They depend on others being vaccinated to make sure they too are safe from vaccine-preventable diseases.
# 0 3
# ['They must be vaccinated since it is one of the most effective procedures for the prevention of infectious diseases.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5215]])
# Similarity on bigger: tensor([[0.0403]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5789]])
# Similarity on bigger: tensor([[0.0403]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.7050]])
# Similarity on bigger: tensor([[0.0403]])
# 1 3
# ['Yes, they must be vaccinated, to stop the infections in the population.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4614]])
# Similarity on bigger: tensor([[-0.0048]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5965]])
# Similarity on bigger: tensor([[-0.0048]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6411]])
# Similarity on bigger: tensor([[-0.0048]])
# 2 3
# ['You should be vaccinated to prevent the spread of a disease or lessen symptoms in the event of contracting a disease.', 'In addition to eventually eradicating the disease'] 2
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5353, 0.1869]])
# Similarity on bigger: tensor([[-0.0002,  0.0060]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5856, 0.2744]])
# Similarity on bigger: tensor([[-0.0002,  0.0060]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6977, 0.3331]])
# Similarity on bigger: tensor([[-0.0002,  0.0060]])
# 3 3
# ['People who have an allergy to any of the components of the vaccine or a state of immunosuppression should not be vaccinated without the permission of their treating physician.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.5182]])
# Similarity on bigger: tensor([[0.0227]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6572]])
# Similarity on bigger: tensor([[0.0227]])
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6479]])
# Similarity on bigger: tensor([[0.0227]])
# =====================================
# Question :  nan
# Reference text :  It is the only effective way to stop pandemics.
# 0 1
# ['It is one of the most effective procedures for the prevention of infectious diseases, such as COVID-19'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4122]])
# Similarity on bigger: tensor([[0.0531]])
# 1 1
# ['There is no risk when getting vaccinated, vaccination is the most important preventive measure both for personal care'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4123]])
# Similarity on bigger: tensor([[0.0374]])
# 2 1
# ['To prevent them from spreading or to end the pandemic'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.6428]])
# Similarity on bigger: tensor([[0.0409]])
# 3 1
# ['It is the only effective way to stop pandemics.'] 1
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[1.]])
# Similarity on bigger: tensor([[0.0368]])

# %%
translated_sample = 'SÍNTOMAS COMUNES Fiebre Tos Malestar general Pérdida del gusto o del olfato SÍNTOMAS COMUNES: Dolor de garganta Dolor de cabeza Diarrea Erupción cutánea Ojos irritados SÍNTOMAS - COMPLICACIONES: Dificultad para respirar o disnea Letargo Dolor en el pecho'
question_sample = '¿Cuáles son los síntomas comunes del COVID-19?'

# %%
#     # Getting the embedding
q_emb = model_p.encode(translated_sample)
p_emb = model_p.encode(question_sample)
                #     # Printing the similarity score 
print("Similarity on bigger:", util.pytorch_cos_sim(q_emb, p_emb))
sim_score = util.pytorch_cos_sim(q_emb, p_emb).cpu().detach().numpy()[0]

                #  Getting the embedding for comparing similarity with the question
                #     # Printing the similarity score 
print("Similarity on bigger:", util.pytorch_cos_sim(q_emb_Q, p_emb))
sim_score_qs = util.pytorch_cos_sim(q_emb_Q, p_emb).cpu().detach().numpy()[0]
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Similarity on bigger: tensor([[0.4031]])
# Similarity on bigger: tensor([[0.1438]])
